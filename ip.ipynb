# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
im = np.array(Image.open('lighthouse.png'))
print(type(im))
# <class 'numpy.ndarray'>

print(im.dtype)
# uint8

print(im.shape)
# (225, 400, 3)
im_gray = np.array(Image.open('lighthouse.png').convert('L'))

print(im_gray.shape)
img = Image.open('lighthouse.png')
img.show()
plt.imshow(img)
# Out:
# <class 'numpy.ndarray'>
# uint8
# (640, 480, 3)
# (640, 480)
